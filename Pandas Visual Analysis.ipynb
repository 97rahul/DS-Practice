# %% [markdown]
# # Pandas Visual Analysis

# %%
import seaborn as sns
from pandas_visual_analysis import VisualAnalysis

# %%
dataset = sns.load_dataset('titanic')
dataset
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
VisualAnalysis(dataset)
# Out:
# ...
# C:\Users\tom97\anaconda3\lib\site-packages\numpy\core\numeric.py:2453: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
sns.histplot(dataset.fare,bins=50)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %% [markdown]
# ## Automated EDA using Pandas Visual Analysis gives the same result as that of manual analysis
# ### Suitable for low to medium size Dataset
