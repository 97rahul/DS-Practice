# %% [markdown]
# # VAEX

# %%
import vaex
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randint(0,100,size = (1000000,500)),columns = ['col%d' % i for i in range(500)])
df.head()
# Out:
#    col0  col1  col2  col3  col4  col5  col6  col7  col8  col9  ...  col490  \
# 0    50    50    70    55    87    70    31    18    71    51  ...      33
# 1    81    35    92    11    70    35    54    68     3    66  ...      29
# 2    89    91    48    59    13    75    80    39     0    15  ...      35
# 3     4    43     1    33    68    97    54    47    62     6  ...       2
# 4    86    74    33    14    74    77    98    90    80    45  ...      66
#
#    col491  col492  col493  col494  col495  col496  col497  col498  col499
# 0      91      29      52      82      67      26      87      70      53
# 1      87      51      60       4      90      62      84      75      70
# 2      26      88       3      26      60      81       8      93      23
# 3       5      43      37      85       4      82       4      45      22
# 4      19      30      52      59       0      50      21       9      87
#
# [5 rows x 500 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Columns: 500 entries, col0 to col499
# dtypes: int32(500)
# memory usage: 1.9 GB

# %%
df.to_csv('sample.csv',index = False)

# %%
vaex_df = vaex.from_csv('sample.csv', convert=True, chunk_size = 5_000_000)
type(vaex_df)
# Out:
# vaex.dataframe.DataFrameLocal

# %%
type(vaex_df)
# Out:
# vaex.dataframe.DataFrameLocal

# %%
vaex_df = vaex.open('sample.csv.hdf5')

# %%
type(vaex_df)
# Out:
# vaex.dataframe.DataFrameLocal

# %%
vaex_df.head()
# Out:
#   #    col0    col1    col2    col3    col4    col5    col6    col7    col8    col9    col10    col11    col12    col13    col14    col15    col16    col17    col18    col19    col20    col21    col22    col23    col24    col25    col26    col27    col28    col29    col30    col31    col32    col33    col34    col35    col36    col37    col38    col39    col40    col41    col42    col43    col44    col45    col46    col47    col48    col49    col50    col51    col52    col53    col54    col55    col56    col57    col58    col59    col60    col61    col62    col63    col64    col65    col66    col67    col68    col69    col70    col71    col72    col73    col74    col75    col76    col77    col78    col79    col80    col81    col82    col83    col84    col85    col86    col87    col88    col89    col90    col91    col92    col93    col94    col95    col96    col97    col98    col99    col100    col101    col102    col103    col104    col105    col106    col107    col108    col109    c
# ...

# %%
# %%time
vaex_df['multiplication_col13']=vaex_df.col1*vaex_df.col3
# Out:
# Wall time: 15.6 ms

# %%
vaex_df['multiplication_col13']
# Out:
# Expression = multiplication_col13
# Length: 1,000,000 dtype: int64 (column)
# ---------------------------------------
#      0  2750
#      1   385
#      2  5369
#      3  1419
#      4  1036
#     ...
# 999995  1040
# 999996   475
# 999997  2852
# 999998  2380
# 999999   395

# %%
vaex_df[vaex_df.col2>70]
# Out:
# #        col0    col1    col2    col3    col4    col5    col6    col7    col8    col9    col10    col11    col12    col13    col14    col15    col16    col17    col18    col19    col20    col21    col22    col23    col24    col25    col26    col27    col28    col29    col30    col31    col32    col33    col34    col35    col36    col37    col38    col39    col40    col41    col42    col43    col44    col45    col46    col47    col48    col49    col50    col51    col52    col53    col54    col55    col56    col57    col58    col59    col60    col61    col62    col63    col64    col65    col66    col67    col68    col69    col70    col71    col72    col73    col74    col75    col76    col77    col78    col79    col80    col81    col82    col83    col84    col85    col86    col87    col88    col89    col90    col91    col92    col93    col94    col95    col96    col97    col98    col99    col100    col101    col102    col103    col104    col105    col106    col107    col108    col109   
# ...

# %%
dff=vaex_df[vaex_df.col2>70]

# %%
dff.col2.minmax(progress='widget')
# Out:
# ...
# array([71, 99], dtype=int64)

# %%
# %%time
vaex_df_group=vaex_df.groupby(vaex_df.col1,agg=vaex.agg.mean(vaex_df.col4))
vaex_df_group
# Out:
# Wall time: 69 ms
# #    col1    col4_mean
# 0    37      49.33575390821987
# 1    12      49.4672032193159
# 2    0       49.39417008915156
# 3    56      49.32534616517726
# 4    68      49.57233346955456
# ...  ...     ...
# 95   11      49.55774029344246
# 96   87      49.26384169498301
# 97   99      49.21473322554567
# 98   64      49.487105157936824
# 99   33      49.1130374479889

# %%
# %%time
vaex_df.groupby(vaex_df.col1,agg='count')
# Out:
# Wall time: 69 ms
# #    col1    count
# 0    37      9915
# 1    12      9940
# 2    0       9983
# 3    56      10183
# 4    68      9788
# ...  ...     ...
# 95   11      10019
# 96   87      10006
# 97   99      9896
# 98   64      10004
# 99   33      10094

# %%
# %%time
vaex_df.col5.mean(progress='widget')
# Out:
# ...
# Wall time: 66 ms
# array(49.502298)

# %%
vaex_df[vaex_df.col40>80]
# Out:
# #        col0    col1    col2    col3    col4    col5    col6    col7    col8    col9    col10    col11    col12    col13    col14    col15    col16    col17    col18    col19    col20    col21    col22    col23    col24    col25    col26    col27    col28    col29    col30    col31    col32    col33    col34    col35    col36    col37    col38    col39    col40    col41    col42    col43    col44    col45    col46    col47    col48    col49    col50    col51    col52    col53    col54    col55    col56    col57    col58    col59    col60    col61    col62    col63    col64    col65    col66    col67    col68    col69    col70    col71    col72    col73    col74    col75    col76    col77    col78    col79    col80    col81    col82    col83    col84    col85    col86    col87    col88    col89    col90    col91    col92    col93    col94    col95    col96    col97    col98    col99    col100    col101    col102    col103    col104    col105    col106    col107    col108    col109   
# ...

# %%
vaex_df[vaex_df.col40>80].col40.minmax(progress = 'widget')
# Out:
# ...
# array([81, 99], dtype=int64)

# %%
vaex_df.groupby(vaex_df.col5,agg = vaex.agg.mean(vaex_df.col40))
# Out:
# #    col5    col40_mean
# 0    0       49.59633481921743
# 1    56      49.81748097717261
# 2    12      49.23086978381096
# 3    37      50.03237264055206
# 4    15      49.627190332326286
# ...  ...     ...
# 95   87      49.437506254378064
# 96   11      49.55292024903647
# 97   99      49.72882195581096
# 98   64      48.80200300450676
# 99   33      49.3285505124451
